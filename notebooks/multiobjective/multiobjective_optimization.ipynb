# %%
from SAES.latex_generation.stats_table import Friedman
from SAES.latex_generation.stats_table import Wilcoxon
from SAES.plots.boxplot import Boxplot
from SAES.plots.CDplot import CDplot
from SAES.plots.Pplot import Pplot

import pandas as pd

# %%
"""
In order to generate the HTML code from the notebook, write this command in the terminal:
jupyter nbconvert --to html --no-input multiobjective_optimization.ipynb

If you do not have jupyter installed, you can use the python terminal:
python -m nbconvert --to html --no-input multiobjective_optimization.ipynb
""";

# %%
# Load the experiment data
experimentData = pd.read_csv('../swarmIntelligence.csv')
metrics = pd.read_csv('../multiobjectiveMetrics.csv')

# %% [markdown]
# # Comparative study of multi-objective metaheuristics

# %% [markdown]
# ## HV quality indicator

# %%
metric = "HV"

# %% [markdown]
# ## Medians table

# %%
friedman = Friedman(experimentData, metrics, metric)
friedman.show()
# Out:
# <style type="text/css">
# #T_1e797_row0_col6, #T_1e797_row1_col6, #T_1e797_row2_col6, #T_1e797_row3_col3, #T_1e797_row4_col6, #T_1e797_row5_col3, #T_1e797_row6_col3, #T_1e797_row7_col3, #T_1e797_row8_col3, #T_1e797_row9_col3, #T_1e797_row10_col6, #T_1e797_row11_col6 {
#   background-color: green;
# }
# </style>
# <table id="T_1e797">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e797_level0_col0" class="col_heading level0 col0" >NSGAII</th>
#       <th id="T_1e797_level0_col1" class="col_heading level0 col1" >SMPSO</th>
#       <th id="T_1e797_level0_col2" class="col_heading level0 col2" >OMOPSO</th>
#       <th id="T_1e797_level0_col3" class="col_heading level0 col3" >AutoMOPSOD</th>
#       <th id="T_1e797_level0_col4" class="col_heading level0 col4" >AutoMOPSOW</th>
#       <th id="T_1e797_level0_col5" class="col_heading level0 col5" >AutoMOPSORE</th>
#       <th id="T_1e797_level0_col6" class="col_heading level0 col6" >AutoMOPSOZ</th>
#       <th id="T_1e797_level0_col7" class="col_heading level0 col7" >Friedman</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e797_level0_row0" class="row_heading level0 row0" >ZDT1</th>
#       <td id="T_1e797_row0_col0" class="data row0 col0" >6.3817e-01</td>
#       <td id="T_1e797_row0_col1" class="data row0 col1" >6.5698e-01</td>
#       <td id="T_1e797_row0_col2" class="data row0 col2" >6.5635e-01</td>
#       <td id="T_1e797_row0_col3" class="data row0 col3" >6.6209e-01</td>
#       <td id="T_1e797_row0_col4" class="data row0 col4" >6.2227e-01</td>
#       <td id="T_1e797_row0_col5" class="data row0 col5" >6.1364e-01</td>
#       <td id="T_1e797_row0_col6" class="data row0 col6" >6.6211e-01</td>
#       <td id="T_1e797_row0_col7" class="data row0 col7" >+</td>
#     </tr>
#     <tr>
#       <th id="T_1e797_level0_row1" class="row_heading level0 row1" >ZDT2</th>
#       <td id="T_1e797_row1_col0" class="data row1 col0" >2.9175e-01</td>
#       <td id="T_1e797_row1_col1" class="data row1 col1" >3.2770e-01</td>
#       <td id="T_1e797_row1_col2" class="data row1 col2" >3.2215e-01</td>
#       <td id="T_1e797_row1_col3" class="data row1 col3" >4.2080e-02</td>
#       <td id="T_1e797_row1_col4" class="data row1 col4" >0.0000e+00</td>
#       <td id="T_1e797_row1_col5" class="data row1 col5" >3.2876e-01</td>
#       <td id="T_1e797_row1_col6" class="data row1 col6" >3.2885e-01</td>
#       <td id="T_1e797_row1_col7" class="data row1 col7" >+</td>
#     </tr>
#     <tr>
#       <th id="T_1e797_level0_row2" class="row_heading level0 row2" >ZDT3</th>
#       <td id="T_1e797_row2_col0" class="data row2 col0" >4.9701e-01</td>
#       <td id="T_1e797_row2_col1" class="data row2 col1" >4.1863e-01</td>
#       <td id="T_1e797_row2_col2" class="data row2 col2" >4.6840e-01</td>
#       <td id="T_1e797_row2_col3" class="data row2 col3" >5.1575e-01</td>
#       <td id="T_1e797_row2_col4" class="data row2 col4" >3.9088e-01</td>
#       <td id="T_1e797_row2_col5" class="data row2 col5" >3.1726e-01</td>
#       <td id="T_1e797_row2_col6" class="data row2 col6" >5.1600e-01</td>
#       <td id="T_1e797_row2_col7" class="data row2 col7" >+</td>
#     </tr>
#     <tr>
#       <th id="T_1e797_level0_row3" class="row_heading level0 row3" >ZDT4</th>
#       <td id="T_1e797_row3_col0" class="data row3 col0" >1.3925e-01</td>
#       <td id="T_1e797_row3_col1" class="data row3 col1" >6.5996e-01</td>
#       <td id="T_1e797_row3_col2" class="data row3 col2" >0.0000e+00</td>
#       <td id="T_1e797_row3_col3" class="data row3 col3" >6.6195e-01</td>
#       <td id="T_1e797_row3_col4" class="data row3 col4" >0.0000e+00</td>
#       <td id="T_1e797_row3_col5" class="data row3 col5" >0.0000e+00</td>
#       <td id="T_1e797_row3_col6" class="data row3 col6" >0.0000e+00</td>
#       <td id="T_1e797_row3_col7" class="data row3 col7" >+</td>
#     </tr>
#     <tr>
#       <th id="T_1e797_level0_row4" class="row_heading level0 row4" >ZDT6</th>
#       <td id="T_1e797_row4_col0" class="data row4 col0" >1.6329e-01</td>
#       <td id="T_1e797_row4_col1" class="data row4 col1" >4.0105e-01</td>
#       <td id="T_1e797_row4_col2" class="data row4 col2" >4.0126e-01</td>
#       <td id="T_1e797_row4_col3" class="data row4 col3" >4.0140e-01</td>
#       <td id="T_1e797_row4_col4" class="data row4 col4" >4.0145e-01</td>
#       <td id="T_1e797_row4_col5" class="data row4 col5" >4.0147e-01</td>
#       <td id="T_1e797_row4_col6" class="data row4 col6" >4.0148e-01</td>
#       <td id="T_1e797_row4_col7" class="data row4 col7" >+</td>
#     </tr>
#     <tr>
#       <th id="T_1e797_level0_row5" class="row_heading level0 row5" >DTLZ1</th>
#       <td id="T_1e797_row5_col0" class="data row5 col0" >0.0000e+00</td>
#       <td id="T_1e797_row5_col1" class="data row5 col1" >4.9324e-01</td>
#       <td id="T_1e797_row5_col2" class="data row5 col2" >0.0000e+00</td>
#       <td id="T_1e797_row5_col3" class="data row5 col3" >4.9464e-01</td>
#       <td id="T_1e797_row5_col4" class="data row5 col4" >0.0000e+00</td>
#       <td id="T_1e797_row5_col5" class="data row5 col5" >0.0000e+00</td>
#       <td id="T_1e797_row5_col6" class="data row5 col6" >0.0000e+00</td>
#       <td id="T_1e797_row5_col7" class="data row5 col7" >+</td>
#     </tr>
#     <tr>
#       <th id="T_1e797_level0_row6" class="row_heading level0 row6" >DTLZ2</th>
#       <td id="T_1e797_row6_col0" class="data row6 col0" >2.0854e-01</td>
#       <td id="T_1e797_row6_col1" class="data row6 col1" >2.0968e-01</td>
#       <td id="T_1e797_row6_col2" class="data row6 col2" >2.0925e-01</td>
#       <td id="T_1e797_row6_col3" class="data row6 col3" >2.1098e-01</td>
#       <td id="T_1e797_row6_col4" class="data row6 col4" >2.0605e-01</td>
#       <td id="T_1e797_row6_col5" class="data row6 col5" >2.0851e-01</td>
#       <td id="T_1e797_row6_col6" class="data row6 col6" >2.0693e-01</td>
#       <td id="T_1e797_row6_col7" class="data row6 col7" >+</td>
#     </tr>
#     <tr>
#       <th id="T_1e797_level0_row7" class="row_heading level0 row7" >DTLZ3</th>
#       <td id="T_1e797_row7_col0" class="data row7 col0" >0.0000e+00</td>
#       <td id="T_1e797_row7_col1" class="data row7 col1" >8.5786e-02</td>
#       <td id="T_1e797_row7_col2" class="data row7 col2" >0.0000e+00</td>
#       <td id="T_1e797_row7_col3" class="data row7 col3" >2.0573e-01</td>
#       <td id="T_1e797_row7_col4" class="data row7 col4" >0.0000e+00</td>
#       <td id="T_1e797_row7_col5" class="data row7 col5" >0.0000e+00</td>
#       <td id="T_1e797_row7_col6" class="data row7 col6" >0.0000e+00</td>
#       <td id="T_1e797_row7_col7" class="data row7 col7" >+</td>
#     </tr>
#     <tr>
#       <th id="T_1e797_level0_row8" class="row_heading level0 row8" >DTLZ4</th>
#       <td id="T_1e797_row8_col0" class="data row8 col0" >2.0850e-01</td>
#       <td id="T_1e797_row8_col1" class="data row8 col1" >2.0966e-01</td>
#       <td id="T_1e797_row8_col2" class="data row8 col2" >2.0809e-01</td>
#       <td id="T_1e797_row8_col3" class="data row8 col3" >2.1098e-01</td>
#       <td id="T_1e797_row8_col4" class="data row8 col4" >1.9253e-01</td>
#       <td id="T_1e797_row8_col5" class="data row8 col5" >2.0635e-01</td>
#       <td id="T_1e797_row8_col6" class="data row8 col6" >2.0595e-01</td>
#       <td id="T_1e797_row8_col7" class="data row8 col7" >+</td>
#     </tr>
#     <tr>
#       <th id="T_1e797_level0_row9" class="row_heading level0 row9" >DTLZ5</th>
#       <td id="T_1e797_row9_col0" class="data row9 col0" >2.1025e-01</td>
#       <td id="T_1e797_row9_col1" class="data row9 col1" >2.1134e-01</td>
#       <td id="T_1e797_row9_col2" class="data row9 col2" >2.1108e-01</td>
#       <td id="T_1e797_row9_col3" class="data row9 col3" >2.1262e-01</td>
#       <td id="T_1e797_row9_col4" class="data row9 col4" >2.0588e-01</td>
#       <td id="T_1e797_row9_col5" class="data row9 col5" >2.1052e-01</td>
#       <td id="T_1e797_row9_col6" class="data row9 col6" >2.0909e-01</td>
#       <td id="T_1e797_row9_col7" class="data row9 col7" >+</td>
#     </tr>
#     <tr>
#       <th id="T_1e797_level0_row10" class="row_heading level0 row10" >DTLZ6</th>
#       <td id="T_1e797_row10_col0" class="data row10 col0" >0.0000e+00</td>
#       <td id="T_1e797_row10_col1

# %% [markdown]
# ## Wilcoxon rank-sum test table

# %%
wilcoxon = Wilcoxon(experimentData, metrics, metric)
wilcoxon.show()
# Out:
# <style type="text/css">
# #T_28a8a_row0_col0, #T_28a8a_row0_col1, #T_28a8a_row0_col2, #T_28a8a_row0_col3, #T_28a8a_row0_col4, #T_28a8a_row0_col5, #T_28a8a_row1_col0, #T_28a8a_row1_col1, #T_28a8a_row1_col2, #T_28a8a_row1_col3, #T_28a8a_row1_col4, #T_28a8a_row1_col5, #T_28a8a_row2_col0, #T_28a8a_row2_col1, #T_28a8a_row2_col2, #T_28a8a_row2_col3, #T_28a8a_row2_col4, #T_28a8a_row2_col5, #T_28a8a_row3_col0, #T_28a8a_row3_col1, #T_28a8a_row3_col2, #T_28a8a_row3_col3, #T_28a8a_row3_col4, #T_28a8a_row3_col5, #T_28a8a_row4_col0, #T_28a8a_row4_col1, #T_28a8a_row4_col2, #T_28a8a_row4_col3, #T_28a8a_row4_col4, #T_28a8a_row4_col5, #T_28a8a_row5_col0, #T_28a8a_row5_col1, #T_28a8a_row5_col2, #T_28a8a_row5_col3, #T_28a8a_row5_col4, #T_28a8a_row5_col5 {
#   font-size: 12px;
#   font-family: monospace;
# }
# </style>
# <table id="T_28a8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28a8a_level0_col0" class="col_heading level0 col0" >SMPSO</th>
#       <th id="T_28a8a_level0_col1" class="col_heading level0 col1" >OMOPSO</th>
#       <th id="T_28a8a_level0_col2" class="col_heading level0 col2" >AutoMOPSOD</th>
#       <th id="T_28a8a_level0_col3" class="col_heading level0 col3" >AutoMOPSOW</th>
#       <th id="T_28a8a_level0_col4" class="col_heading level0 col4" >AutoMOPSORE</th>
#       <th id="T_28a8a_level0_col5" class="col_heading level0 col5" >AutoMOPSOZ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28a8a_level0_row0" class="row_heading level0 row0" >NSGAII</th>
#       <td id="T_28a8a_row0_col0" class="data row0 col0" >=-+---------</td>
#       <td id="T_28a8a_row0_col1" class="data row0 col1" >--++---==--=</td>
#       <td id="T_28a8a_row0_col2" class="data row0 col2" >-=----------</td>
#       <td id="T_28a8a_row0_col3" class="data row0 col3" >++++--+=++==</td>
#       <td id="T_28a8a_row0_col4" class="data row0 col4" >+=++--====-=</td>
#       <td id="T_28a8a_row0_col5" class="data row0 col5" >---+--+==+--</td>
#     </tr>
#     <tr>
#       <th id="T_28a8a_level0_row1" class="row_heading level0 row1" >SMPSO</th>
#       <td id="T_28a8a_row1_col0" class="data row1 col0" ></td>
#       <td id="T_28a8a_row1_col1" class="data row1 col1" >=+=+-++++==+</td>
#       <td id="T_28a8a_row1_col2" class="data row1 col2" >-+---------=</td>
#       <td id="T_28a8a_row1_col3" class="data row1 col3" >=+=+-+++++++</td>
#       <td id="T_28a8a_row1_col4" class="data row1 col4" >==++-+++++-=</td>
#       <td id="T_28a8a_row1_col5" class="data row1 col5" >---+-+++++--</td>
#     </tr>
#     <tr>
#       <th id="T_28a8a_level0_row2" class="row_heading level0 row2" >OMOPSO</th>
#       <td id="T_28a8a_row2_col0" class="data row2 col0" ></td>
#       <td id="T_28a8a_row2_col1" class="data row2 col1" ></td>
#       <td id="T_28a8a_row2_col2" class="data row2 col2" >-+----------</td>
#       <td id="T_28a8a_row2_col3" class="data row2 col3" >=+==-=+=+++=</td>
#       <td id="T_28a8a_row2_col4" class="data row2 col4" >+=+=-====+-=</td>
#       <td id="T_28a8a_row2_col5" class="data row2 col5" >---=-=+=++--</td>
#     </tr>
#     <tr>
#       <th id="T_28a8a_level0_row3" class="row_heading level0 row3" >AutoMOPSOD</th>
#       <td id="T_28a8a_row3_col0" class="data row3 col0" ></td>
#       <td id="T_28a8a_row3_col1" class="data row3 col1" ></td>
#       <td id="T_28a8a_row3_col2" class="data row3 col2" ></td>
#       <td id="T_28a8a_row3_col3" class="data row3 col3" >++++=+++++++</td>
#       <td id="T_28a8a_row3_col4" class="data row3 col4" >+=++-+++++-+</td>
#       <td id="T_28a8a_row3_col5" class="data row3 col5" >---+-+++++--</td>
#     </tr>
#     <tr>
#       <th id="T_28a8a_level0_row4" class="row_heading level0 row4" >AutoMOPSOW</th>
#       <td id="T_28a8a_row4_col0" class="data row4 col0" ></td>
#       <td id="T_28a8a_row4_col1" class="data row4 col1" ></td>
#       <td id="T_28a8a_row4_col2" class="data row4 col2" ></td>
#       <td id="T_28a8a_row4_col3" class="data row4 col3" ></td>
#       <td id="T_28a8a_row4_col4" class="data row4 col4" >=-==-=-=----</td>
#       <td id="T_28a8a_row4_col5" class="data row4 col5" >---=-===----</td>
#     </tr>
#     <tr>
#       <th id="T_28a8a_level0_row5" class="row_heading level0 row5" >AutoMOPSORE</th>
#       <td id="T_28a8a_row5_col0" class="data row5 col0" ></td>
#       <td id="T_28a8a_row5_col1" class="data row5 col1" ></td>
#       <td id="T_28a8a_row5_col2" class="data row5 col2" ></td>
#       <td id="T_28a8a_row5_col3" class="data row5 col3" ></td>
#       <td id="T_28a8a_row5_col4" class="data row5 col4" ></td>
#       <td id="T_28a8a_row5_col5" class="data row5 col5" >---===+===--</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Critical distance ranking

# %%
cdplot = CDplot(experimentData, metrics, metric)
cdplot.show()

# %% [markdown]
# ## Boxplots

# %%
boxplot = Boxplot(experimentData, metrics, metric)
boxplot.show_all_instances()

# %% [markdown]
# ## Bayesian Posterior Plots

# %%
pplot = Pplot(experimentData, metrics, metric)
pplot.show_pivot("AutoMOPSOD", heigth=17)
